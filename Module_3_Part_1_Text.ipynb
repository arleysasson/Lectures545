# %%
# !pip install afinn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting afinn
#   Downloading afinn-0.1.tar.gz (52 kB)
#      |████████████████████████████████| 52 kB 326 kB/s
# Building wheels for collected packages: afinn
#   Building wheel for afinn (setup.py) ... done
#   Created wheel for afinn: filename=afinn-0.1-py3-none-any.whl size=53447 sha256=927ba6fd0ff41a9ee06ffc082fef6d946ce899c380021716c98758842db257fa
#   Stored in directory: /root/.cache/pip/wheels/9d/16/3a/9f0953027434eab5dadf3f33ab3298fa95afa8292fcf7aba75
# Successfully built afinn
# Installing collected packages: afinn
# Successfully installed afinn-0.1

# %%
import pandas as pd
from afinn import Afinn

# %%
reviews_df = pd.read_csv('https://penn-cis545-files.s3.amazonaws.com/GrammarandProductReviews.csv')

# %%
food_df = reviews_df[reviews_df['categories'].apply(lambda x: 'Food,' in x)]

food_df
# Out:
#                          id        brand  \
# 1      AV14LG0R-jtxr-f38QfS     Lundberg
# 2      AV14LG0R-jtxr-f38QfS     Lundberg
# 1055   AV1YIch7GV-KLJ3addeG        Heinz
# 1056   AV1YlENIglJLPUi8IHsX         KIND
# 1057   AV1YlENIglJLPUi8IHsX         KIND
# ...                     ...          ...
# 68474  AVq5UzjHU2_QcyX9O584  Nutri-Grain
# 70252  AVsRL7C9U2_QcyX9PFuJ     Skittles
# 70253  AVsRL7C9U2_QcyX9PFuJ     Skittles
# 70254  AVsRL7C9U2_QcyX9PFuJ     Skittles
# 70255  AVsRL7C9U2_QcyX9PFuJ     Skittles
#
#                                               categories  \
# 1      Food,Packaged Foods,Snacks,Crackers,Snacks, Co...
# 2      Food,Packaged Foods,Snacks,Crackers,Snacks, Co...
# 1055   Food,Packaged Foods,Condiments, Dips, & Salad ...
# 1056   Food,Packaged Foods,Snacks,Cereal Bars and Gra...
# 1057   Food,Packaged Foods,Snacks,Cereal Bars and Gra...
# ...                                                  ...
# 68474  Food,Packaged Foods,Snacks,Cereal Bars and Gra...
# 70252  Food & Beverage,Candy & Gum,Gummy & Chewy Cand...
# 70253  Food & Beverage,Candy & Gum,Gummy & Chewy Cand...
# 70254  Food & Beverage,Candy & Gum,Gummy & Chewy Cand...
# 70255  Food & Beverage,Candy & Gum,Gummy & Chewy Cand...
#
#                   dateAdded           dateUpdated          ean  \
# 1      2017-07-25T05:16:03Z  2018-02-05T11:27:45Z  73416000391
# 2      2017-07-25T05:16:03Z  2018-02-05T11:27:45Z  73416000391
# 1055   2017-07-18T23:56:35Z  2018-02-05T11:26:35Z  13000004664
# 1056   2017-07-19T02:01:37Z  2018-02-05T11:26:49Z  6.02652E+11
# 1057   2017-07-19T02:01:37Z  2018-02-05T11:26:49Z  6.02652E+11
# ...                     ...                   ...          ...
# 68474  2017-03-10T17:45:23Z  2018-02-05T11:28:54Z  38000355004
# 70252  2017-03-27T19:13:09Z  2018-01-30T06:11:23Z  22000123701
# 70253  2017-03-27T19:13:09Z  2018-01-30T06:11:23Z  22000123701
# 70254  2017-03-27T19:13:09Z  2018-01-30T06:11:23Z  22000123701
# 70255  2017-03-27T19:13:09Z  2018-01-30T06:11:23Z  22000123701
#
#                                                     keys  \
# 1      lundbergorganiccinnamontoastricecakes/b000fvzw...
# 2      lundbergorganiccinnamontoastricecakes/b000fvzw...
# 1055   heinztomatoketchup38oz/b00b0yhrc4,013000004664...
# 1056   602652184024,kind/15027059,darkchocolatechunkg...
# 1057   602652184024,kind/15027059,darkchocolatechunkg...
# ...                                                  ...
# 68474  nutrigraincerealbarsmixedberry8ct/b000aydhaq,0...
# 70252  022000123701,0022000123701,skittlesoriginalcan...
# 70253  022000123701,0022000123701,skittlesoriginalcan...
# 70254  022000123701,0022000123701,skittlesoriginalcan...
# 70255  022000123701,0022000123701,skittlesoriginalcan...
#
#                 manufacturer manufacturerNumber  \
# 1                   Lundberg             574764
# 2                   Lundberg             574764
# 1055     Heinz North America           13400436
# 1056   Kind Fruit & Nut Bars           15027059
# 1057   Kind Fruit & Nut Bars           15027059
# ...                      ...                ...
# 68474            Nutri-Grain           12992472
# 70252               Skittles           14709696
# 70253               Skittles           14709696
# 70254               Skittles           14709696
# 70255               Skittles           14709696
#
#                                                     name  ...   reviews.id  \
# 1             Lundberg Organic Cinnamon Toast Rice Cakes  ...  100209113.0
# 2             Lundberg Organic Cinnamon Toast Rice Cakes  ...  100209113.0
# 1055                          Heinz Tomato Ketchup, 38oz  ...          NaN
# 1056   Kind Dark Chocolate Chunk Gluten Free Granola ...  ...  104821113.0
# 1057   Kind Dark Chocolate Chunk Gluten Free Granola ...  ...   33383690.0
# ...                                                  ...  ...          ...
# 68474         Nutrigrain Cereal Bars, Mixed Berry, 8 Ct.  ...   68337917.0
# 70252                  Skittles Original Candy Bag - 9oz  ...          NaN
# 70253                  Skittles Original Candy Bag - 9oz  ...   94372630.0
# 70254                  Skittles Original Candy Bag - 9oz  ...   94718519.0
# 70255                  Skittles Original Candy Bag - 9oz  ...   91877068.0
#
#       reviews.numHelpful reviews.rating  \
# 1                    NaN              5
# 2                    NaN              5
# 1055                 1.0              5
# 1056                 0.0              1
# 1057                 0.0              2
# ...                  ...            ...
# 68474                0.0              5
# 70252                NaN              1
# 70253                NaN              1
# 70254                NaN              5
# 70255                NaN              5
#
#                                       reviews.sourceURLs  \
# 1       https://www.walmart.com/reviews/product/29775278
# 2       https://www.walmart.com/reviews/product/29775278
# 1055   https://redsky.target.com/groot-domain-api/v1/...
# 1056    https://www.walmart.com/reviews/product/34202687
# 1057    https://www.walmart.com/reviews/product/34202687
# ...                                                  ...
# 68474  https://www.walmart.com/reviews/product/108186...
# 70252  https://redsky.target.com/groot-domain-api/v1/...
# 70253  https://www.walmart.com/reviews/product/118276856
# 70254  https://www.walmart.com/reviews/product/118276856
# 70255  https://www.walmart.com/reviews/product/118276856
#
#                                             reviews.text  \
# 1      Good flavor. This review was collected as part...
# 2                                           Good flavor.
# 1055   I consider myself a ketchup snob. I'll pass on...
# 1056   Buyer beware, these taste like 55, nothing eve...
# 1057   Not being a Kind Bar aficionado, I didn't know...
# ...                                                  ...
# 68474          Love this product! I buy it all the time.
# 70252  Skittles needs to bring back the lime or take ...
# 70253  Skittles needs to bring back the lime or take ...
# 70254  Love them This review was collected as part of...
# 70255  If it was good enough for E.T. then it's good ...
#
#                       reviews.title  reviews.userCity  reviews.userProvince  \
# 1                              Good               NaN                   NaN
# 2                              Good               NaN                   NaN
# 1055             Ketchup Is Awesome               NaN                   NaN
# 1056   definetaly not a granola bar               NaN                   NaN
# 1057                 They were okay               NaN                   NaN
# ...                             ...               ...                   ...
# 68474                   Nutri grain               NaN                   NaN
# 70252           Where's The Lime At    Virginia Beach                   NaN
# 70253           Where's the lime at               NaN                   NaN
# 70254                         tangy               NaN                   NaN
# 70255                   Great Candy               NaN                   NaN
#
#       reviews.username                             upc
# 1            Dorothy W                     73416000391
# 2            Dorothy W                     73416000391
# 1055         Raenicson                     13000004664
# 1056        walmartian                     6.02652E+11
# 1057       LaurieB4041                     6.02652E+11
# ...                ...                             ...
# 68474           Tammie  38,000,355,004,490,700,000,000
# 70252            Hails                     22000123701
# 70253            Hails                     22000123701
# 70254         Joanna b                     22000123701
# 70255     TheHappyCook                     22000123701
#
# [2776 rows x 25 columns]

# %%
reviews_text_df = food_df[['manufacturer','manufacturerNumber','name','reviews.text']].copy()

reviews_text_df
# Out:
#                 manufacturer manufacturerNumber  \
# 1                   Lundberg             574764
# 2                   Lundberg             574764
# 1055     Heinz North America           13400436
# 1056   Kind Fruit & Nut Bars           15027059
# 1057   Kind Fruit & Nut Bars           15027059
# ...                      ...                ...
# 68474            Nutri-Grain           12992472
# 70252               Skittles           14709696
# 70253               Skittles           14709696
# 70254               Skittles           14709696
# 70255               Skittles           14709696
#
#                                                     name  \
# 1             Lundberg Organic Cinnamon Toast Rice Cakes
# 2             Lundberg Organic Cinnamon Toast Rice Cakes
# 1055                          Heinz Tomato Ketchup, 38oz
# 1056   Kind Dark Chocolate Chunk Gluten Free Granola ...
# 1057   Kind Dark Chocolate Chunk Gluten Free Granola ...
# ...                                                  ...
# 68474         Nutrigrain Cereal Bars, Mixed Berry, 8 Ct.
# 70252                  Skittles Original Candy Bag - 9oz
# 70253                  Skittles Original Candy Bag - 9oz
# 70254                  Skittles Original Candy Bag - 9oz
# 70255                  Skittles Original Candy Bag - 9oz
#
#                                             reviews.text
# 1      Good flavor. This review was collected as part...
# 2                                           Good flavor.
# 1055   I consider myself a ketchup snob. I'll pass on...
# 1056   Buyer beware, these taste like 55, nothing eve...
# 1057   Not being a Kind Bar aficionado, I didn't know...
# ...                                                  ...
# 68474          Love this product! I buy it all the time.
# 70252  Skittles needs to bring back the lime or take ...
# 70253  Skittles needs to bring back the lime or take ...
# 70254  Love them This review was collected as part of...
# 70255  If it was good enough for E.T. then it's good ...
#
# [2776 rows x 4 columns]

# %%
reviews_text_df.dtypes
# Out:
# manufacturer          object
# manufacturerNumber    object
# name                  object
# reviews.text          object
# dtype: object

# %%
afinn = Afinn(language='en')

reviews_text_df['score'] = reviews_text_df['reviews.text'].apply(afinn.score)

# %%
reviews_text_df
# Out:
#                 manufacturer manufacturerNumber  \
# 1                   Lundberg             574764
# 2                   Lundberg             574764
# 1055     Heinz North America           13400436
# 1056   Kind Fruit & Nut Bars           15027059
# 1057   Kind Fruit & Nut Bars           15027059
# ...                      ...                ...
# 68474            Nutri-Grain           12992472
# 70252               Skittles           14709696
# 70253               Skittles           14709696
# 70254               Skittles           14709696
# 70255               Skittles           14709696
#
#                                                     name  \
# 1             Lundberg Organic Cinnamon Toast Rice Cakes
# 2             Lundberg Organic Cinnamon Toast Rice Cakes
# 1055                          Heinz Tomato Ketchup, 38oz
# 1056   Kind Dark Chocolate Chunk Gluten Free Granola ...
# 1057   Kind Dark Chocolate Chunk Gluten Free Granola ...
# ...                                                  ...
# 68474         Nutrigrain Cereal Bars, Mixed Berry, 8 Ct.
# 70252                  Skittles Original Candy Bag - 9oz
# 70253                  Skittles Original Candy Bag - 9oz
# 70254                  Skittles Original Candy Bag - 9oz
# 70255                  Skittles Original Candy Bag - 9oz
#
#                                             reviews.text  score
# 1      Good flavor. This review was collected as part...    3.0
# 2                                           Good flavor.    3.0
# 1055   I consider myself a ketchup snob. I'll pass on...    0.0
# 1056   Buyer beware, these taste like 55, nothing eve...    2.0
# 1057   Not being a Kind Bar aficionado, I didn't know...    9.0
# ...                                                  ...    ...
# 68474          Love this product! I buy it all the time.    3.0
# 70252  Skittles needs to bring back the lime or take ...    0.0
# 70253  Skittles needs to bring back the lime or take ...    0.0
# 70254  Love them This review was collected as part of...    3.0
# 70255  If it was good enough for E.T. then it's good ...    6.0
#
# [2776 rows x 5 columns]

# %%
reviews_text_df['score'].describe()
# Out:
# count    2776.000000
# mean        4.229467
# std         4.014336
# min       -10.000000
# 25%         2.000000
# 50%         3.000000
# 75%         6.000000
# max        37.000000
# Name: score, dtype: float64

# %%
reviews_text_df[['manufacturer','manufacturerNumber','name','score']].groupby(
    by=['manufacturer','name','manufacturerNumber']).mean().sort_values(by='score')
# Out:
#                                                                                                                              score
# manufacturer                                      name                                               manufacturerNumber
# Horizon Organic                                   Horizon174 Organic Unsalted Butter - 1lbs          14729221            -8.000000
# Ortega                                            Ortega Thick & Chunky Mild Salsa                   00G6ICL6V5KH315     -1.000000
# Unilever                                          Klondike Choco Tacos Original                      13752636            -1.000000
# Heinz North America                               Heinz Tomato Ketchup, 38oz                         13400436             0.000000
# Newman's Own, Inc.                                Newman's Own Beef & Broccoli Complete Skillet Meal 14802441             0.000000
# ...                                                                                                                            ...
# Season                                            Season Seafood Sardine Fillets In Sweet & Tangy... 0066ISHKOJT9CJ6      8.000000
# Unilever                                          Ben & Jerry's Coffee, Coffee Buzzbuzzbuzz! Ice ... 15004292             8.454545
# Dreyer's Grand Ice Cream/Nestle Ice Cream Company Haagen-Dazs Gelato, Sea Salt Caramel               14936473             8.500000
# Unfi                                              Noosa Honey Yogurt                                 109078-6             9.000000
# NURTURE INC                                       Happy Tot Apple and Butternut Squash               130                 11.222222
#
# [119 rows x 1 columns]

# %%
import nltk

nltk.download('punkt')
nltk.download('twitter_samples')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('ieer')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package twitter_samples to /root/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package ieer to /root/nltk_data...
# [nltk_data]   Package ieer is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
paragraph = '"Data Science" is a misnomer. Science, in general, is a set of methods for learning about the world. ' +\
'Specific sciences are the application of these methods to particular areas of study. Physics is a science: it is the study of physical phenomena.' +\
'Psychology is a science: it is the study of the psyche (i.e., the human mind). There is no science of data.'

sentences = nltk.sent_tokenize(paragraph)

sentences
# Out:
# ['"Data Science" is a misnomer.',
#  'Science, in general, is a set of methods for learning about the world.',
#  'Specific sciences are the application of these methods to particular areas of study.',
#  'Physics is a science: it is the study of physical phenomena.Psychology is a science: it is the study of the psyche (i.e., the human mind).',
#  'There is no science of data.']

# %%
from nltk.tokenize import word_tokenize

for sent in sentences:
  words = word_tokenize(sent)
  words = [word.lower() for word in words if word.isalpha()]
  print (words)
# Out:
# ['data', 'science', 'is', 'a', 'misnomer']
# ['science', 'in', 'general', 'is', 'a', 'set', 'of', 'methods', 'for', 'learning', 'about', 'the', 'world']
# ['specific', 'sciences', 'are', 'the', 'application', 'of', 'these', 'methods', 'to', 'particular', 'areas', 'of', 'study']
# ['physics', 'is', 'a', 'science', 'it', 'is', 'the', 'study', 'of', 'physical', 'is', 'a', 'science', 'it', 'is', 'the', 'study', 'of', 'the', 'psyche', 'the', 'human', 'mind']
# ['there', 'is', 'no', 'science', 'of', 'data']

# %% [markdown]
# ## Part-of-speech tagging
#
# Let's parse the words and see what parts of speech they belong to.  The abbreviations are at https://pythonprogramming.net/natural-language-toolkit-nltk-part-speech-tagging/

# %%
nouns = []

# Tag for parts of speech:
for sent in sentences:
  words = word_tokenize(sent)
  words = [word.lower() for word in words if word.isalpha()]
  print (nltk.pos_tag(words))

  for (w,pos) in nltk.pos_tag(words):
    if pos == 'NN' or pos == 'NNS':
      nouns.append(w)

print ('All nouns in the document:', nouns)
# Out:
# [('data', 'NNS'), ('science', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('misnomer', 'NN')]
# [('science', 'NN'), ('in', 'IN'), ('general', 'JJ'), ('is', 'VBZ'), ('a', 'DT'), ('set', 'NN'), ('of', 'IN'), ('methods', 'NNS'), ('for', 'IN'), ('learning', 'VBG'), ('about', 'IN'), ('the', 'DT'), ('world', 'NN')]
# [('specific', 'JJ'), ('sciences', 'NNS'), ('are', 'VBP'), ('the', 'DT'), ('application', 'NN'), ('of', 'IN'), ('these', 'DT'), ('methods', 'NNS'), ('to', 'TO'), ('particular', 'JJ'), ('areas', 'NNS'), ('of', 'IN'), ('study', 'NN')]
# [('physics', 'NNS'), ('is', 'VBZ'), ('a', 'DT'), ('science', 'NN'), ('it', 'PRP'), ('is', 'VBZ'), ('the', 'DT'), ('study', 'NN'), ('of', 'IN'), ('physical', 'JJ'), ('is', 'VBZ'), ('a', 'DT'), ('science', 'NN'), ('it', 'PRP'), ('is', 'VBZ'), ('the', 'DT'), ('study', 'NN'), ('of', 'IN'), ('the', 'DT'), ('psyche', 'NN'), ('the', 'DT'), ('human', 'JJ'), ('mind', 'NN')]
# [('there', 'EX'), ('is', 'VBZ'), ('no', 'DT'), ('science', 'NN'), ('of', 'IN'), ('data', 'NNS')]
# All nouns in the document: ['data', 'science', 'misnomer', 'science', 'set', 'methods', 'world', 'sciences', 'application', 'methods', 'areas', 'study', 'physics', 'science', 'study', 'science', 'study', 'psyche', 'mind', 'science', 'data']

# %%
# Noun phrase = optional determiner, 0 or more adjectives, noun
pattern = 'NP: {<DT>?(<CD>|<JJ>)*(<NN>|<NNS>|<NNP>|<NNPS>)+}'

# Example sentence.  BERT and ERNIE are now neural net models, not just
# Sesame Street characters
sent = 'Bert and Ernie are two Muppets who appear together in numerous skits on the popular children\'s television show of the United States, Sesame Street.'

cp = nltk.RegexpParser(pattern)
print(cp.parse(nltk.pos_tag(nltk.word_tokenize(sent))))
# Out:
# (S
#   (NP Bert/NNP)
#   and/CC
#   (NP Ernie/NNP)
#   are/VBP
#   (NP two/CD Muppets/NNS)
#   who/WP
#   appear/VBP
#   together/RB
#   in/IN
#   (NP numerous/JJ skits/NNS)
#   on/IN
#   (NP the/DT popular/JJ children/NNS)
#   's/POS
#   (NP television/NN show/NN)
#   of/IN
#   (NP the/DT United/NNP States/NNPS)
#   ,/,
#   (NP Sesame/NNP Street/NNP)
#   ./.)
